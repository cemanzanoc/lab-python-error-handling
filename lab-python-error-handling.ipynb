# %% [markdown]
# # Lab | Error Handling

# %% [markdown]
# ## Exercise: Error Handling for Managing Customer Orders
#
# The implementation of your code for managing customer orders assumes that the user will always enter a valid input.
#
# For example, we could modify the `initialize_inventory` function to include error handling.
#    - If the user enters an invalid quantity (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the quantity for that product.
#    - Use a try-except block to handle the error and continue prompting the user until a valid quantity is entered.
#
# ```python
# # Step 1: Define the function for initializing the inventory with error handling
# def initialize_inventory(products):
#     inventory = {}
#     for product in products:
#         valid_quantity = False
#         while not valid_quantity:
#             try:
#                 quantity = int(input(f"Enter the quantity of {product}s available: "))
#                 if quantity < 0:
#                     raise ValueError("Invalid quantity! Please enter a non-negative value.")
#                 valid_quantity = True
#             except ValueError as error:
#                 print(f"Error: {error}")
#         inventory[product] = quantity
#     return inventory
#
# # Or, in another way:
#
# def initialize_inventory(products):
#     inventory = {}
#     for product in products:
#         valid_input = False
#         while not valid_input:
#             try:
#                 quantity = int(input(f"Enter the quantity of {product}s available: "))
#                 if quantity >= 0:
#                     inventory[product] = quantity
#                     valid_input = True
#                 else:
#                     print("Quantity cannot be negative. Please enter a valid quantity.")
#             except ValueError:
#                 print("Invalid input. Please enter a valid quantity.")
#     return inventory
# ```
#
# Let's enhance your code by implementing error handling to handle invalid inputs.
#
# Follow the steps below to complete the exercise:
#
# 2. Modify the `calculate_total_price` function to include error handling.
#    - If the user enters an invalid price (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the price for that product.
#    - Use a try-except block to handle the error and continue prompting the user until a valid price is entered.
#
# 3. Modify the `get_customer_orders` function to include error handling.
#    - If the user enters an invalid number of orders (e.g., a negative value or a non-numeric value), display an error message and ask them to re-enter the number of orders.
#    - If the user enters an invalid product name (e.g., a product name that is not in the inventory), or that doesn't have stock available, display an error message and ask them to re-enter the product name. *Hint: you will need to pass inventory as a parameter*
#    - Use a try-except block to handle the error and continue prompting the user until a valid product name is entered.
#
# 4. Test your code by running the program and deliberately entering invalid quantities and product names. Make sure the error handling mechanism works as expected.

# %%
#1. Define a function named `initialize_inventory` that takes `products` as a parameter.
# Inside the function, implement the code for initializing the inventory dictionary using a loop and user input.

#List comprehension of function 1.
       
def initialize_inventory(products):
    inventory = {}
    for product in products:
        valid_input = False
        while not valid_input:
            try:
                quantity = int(input(f"Enter the quantity of {product}s available: "))
                print(f"Enter the quantity of {product}:{quantity}")
                if quantity >= 0:
                    inventory[product] = quantity
                    valid_input = True
                else:
                    print("Quantity cannot be negative. Please enter a valid quantity.")
            except ValueError:
                print("Invalid input. Please enter a valid quantity.")
    
    return inventory

#2.Define a fuction name "get_customers_orders". Implement the code for prompting the user to enter the product names using a loop.
#The fuction should return "customer_orders" set

def get_customer_orders(products,inventory) :

    #Error handling invalid numnbers
    num_orders=0
    while num_orders<=0:
        try:
            num_orders = max(0,int(input("How many products would you like to order?")))
            if num_orders<=0:
                print("Number of orders must be higher than 0.Please, try again.")
            
        except ValueError:
            print("Invalid input.Please enter a valid number of products you would like to order")

    #Define customer orders set
    customer_orders = set()
    
    #Error handling invalid product or out of stock in inventory, so should not be added to customer_orders
    for i in range(num_orders):
        order_valid=False
        while not order_valid:
            try: 
            
                product=input(f"Enter the name of a product that a customer wants to order(valid products: {products}): ").strip().lower()
        
                if product not in inventory:
                    print("This product is not in inventory")
                elif inventory[product]==0:
                    print(f"Sorry. {product} out of stock")
                else:
                    customer_orders.add(product)
                    order_valid=True

            except ValueError:
                print("Invalid input. Please enter a valid number") 
        #Print customer order
        print(f"Customer orders:{customer_orders}")
    return customer_orders



#3.Define a new fuction that calculates the total price of the customer order

def pricing_customer_order(customer_orders):

    total_price=0
    
    for order in customer_orders:
        while True:
            try:
                price=max(0, float(input(f"Enter the price of {order}:")))
                print(f"\nEnter the price of {order}:{price}")
                total_price+=price
                break
            except ValueError:
                print("Invalid input. Please, enter a valid price")
    
    print(f"\nThe total price of your customer order is {total_price:.2f}")
    return

#3. Define a fuction named "updated_inventory". Inside the fuction update the inventory dictionary based on customers orders

def updated_inventory(customer_orders,inventory) :

    inventory = {product: inventory[product] - 1 if product in customer_orders else inventory[product] for product in inventory}
    inventory = {product: quantity for product, quantity in inventory.items() if quantity > 0}
    return inventory



#4. Define a fuction named "calculated_orders_statistics". Implement code for calculating order statistics


def calculated_orders_statistics(customer_orders, products) :

    #7.1 Total products ordered
    total_products_ordered=len(customer_orders)
    total_available_products=len(products)
    print(f"\nTotal products ordered: {total_products_ordered}")


    #7.2 Percentage of products ordered
    percentage_ordered=(total_products_ordered/total_available_products)*100
    print(f"Percentage ordered compared to the total available products {percentage_ordered}%") 

    
    return total_products_ordered,percentage_ordered


#5. Define a fuction named "print_order_statistics". Implement code for printing

def print_order_statistics(order_statistics) :
    total_products_ordered, percentage_ordered = order_statistics
    print(f"\nOrder Statistics:\nTotal Products Ordered: {total_products_ordered}\nPercentage of Products Ordered: {percentage_ordered:.2f}%\n")
    

#6. Define a fuction named "print_updated_inventory". Implement code for printing

def print_updated_inventory(inventory) :

    #10.Print the Updated inventory
    print("\nUpdated inventory:")
    for item,quantity in inventory.items() :
        print(f"{item}:{quantity}")




#7. Called the fuctions.

#Define a list called products with different fashion clothes
products=["t-shirt","mug","hat","book","keychain"]

#Inicilize inventory
inventory=initialize_inventory(products)
#Obtein order
customer_orders=get_customer_orders(products,inventory)
#Calculate statistics
order_statistics=calculated_orders_statistics(customer_orders, products)
#Print statistics
print_order_statistics(order_statistics)
#Update inventory
inventory=updated_inventory(customer_orders,inventory)
#Print inventory
print_updated_inventory(inventory)
#Print total price
pricing_customer_order(customer_orders)
# Out:
# Enter the quantity of t-shirt:3
# Enter the quantity of mug:2
# Enter the quantity of hat:0
# Enter the quantity of book:4
# Enter the quantity of keychain:-1
# Quantity cannot be negative. Please enter a valid quantity.
# Enter the quantity of keychain:1
# Customer orders:{'t-shirt'}
# Customer orders:{'t-shirt', 'mug'}
# Customer orders:{'t-shirt', 'book', 'mug'}
# Sorry. hat out of stock
# Customer orders:{'t-shirt', 'book', 'keychain', 'mug'}
# Customer orders:{'t-shirt', 'book', 'keychain', 'mug'}
# Customer orders:{'t-shirt', 'book', 'keychain', 'mug'}
# Sorry. hat out of stock
# Customer orders:{'t-shirt', 'book', 'keychain', 'mug'}
# Customer orders:{'t-shirt', 'book', 'keychain', 'mug'}
#
# Total products ordered: 4
# Percentage ordered compared to the total available products 80.0%
#
# Order Statistics:
# Total Products Ordered: 4
# Percentage of Products Ordered: 80.00%
#
#
# Updated inventory:
# t-shirt:2
# mug:1
# book:3
#
# Enter the price of t-shirt:5.0
#
# ...
